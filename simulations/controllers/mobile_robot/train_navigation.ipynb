# %%
from __future__ import annotations
import math
import os
import csv
from collections import deque
import numpy as np
from stable_baselines3.common.callbacks import (
    BaseCallback,
    CheckpointCallback,
    CallbackList,
)
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv

from train_navigation_env import TwoWheelNavigationEnv, TwoWheelRobotWithoutObstacles

# %%
class CSVMetricsLogger(BaseCallback):
    def __init__(
        self,
        verbose: int = 0,
        rollout_window: int = 100,
        path_episodes="episodes.csv",
    ):
        super().__init__(verbose)
        self.path_episodes = path_episodes
        self.rollout_window = int(rollout_window)

        self._ep_fp = None
        self._ep_writer = None
        self._step_fp = None
        self._step_writer = None

        self._ep_return = 0.0
        self._ep_len = 0

        self._ret_window = deque(maxlen=self.rollout_window)
        self._len_window = deque(maxlen=self.rollout_window)
        self._success_window = deque(maxlen=self.rollout_window)
        self._failure_window = deque(maxlen=self.rollout_window)

    def _on_training_start(self) -> None:
        os.makedirs(os.path.dirname(self.path_episodes) or ".", exist_ok=True)
        self._ep_fp = open(self.path_episodes, "w", newline="")
        self._ep_writer = csv.DictWriter(
            self._ep_fp,
            fieldnames=[
                "timesteps",
                "episode",
                "ep_return",
                "ep_len",
                f"rollout_ep_rew_mean_{self.rollout_window}",
                f"rollout_ep_len_mean_{self.rollout_window}",
                f"rollout_avg_success_{self.rollout_window}",
                f"rollout_avg_failure_{self.rollout_window}",
                f"rollout_success_rate_{self.rollout_window}",
                "success",
                "failure",
                "final_dist",
                "path_len",
                "straight_dist",
                "path_eff",
                "reverse_ratio",
                "heading_abs_mean",
                "action_smooth_mean",
            ],
        )
        self._ep_writer.writeheader()

        self._ep_return = 0.0
        self._ep_len = 0
        self._ret_window.clear()
        self._len_window.clear()
        self._success_window.clear()
        self._failure_window.clear()
        setattr(self, "_episode_idx", 0)

    def _on_step(self) -> bool:
        rewards = self.locals.get("rewards")
        dones = self.locals.get("dones")
        infos = self.locals.get("infos")

        if rewards is None or dones is None or infos is None:
            return True

        r = float(rewards[0])
        done = bool(dones[0])
        info = infos[0]

        self._ep_return += r
        self._ep_len += 1

        if done and self._ep_writer is not None:
            ep_idx = int(getattr(self, "_episode_idx", 0))

            self._ret_window.append(float(self._ep_return))
            self._len_window.append(int(self._ep_len))

            success = float(info.get("ep_success", info.get("success", False)))
            failure = float(info.get("ep_failure", 1.0 - success))

            self._success_window.append(success)
            self._failure_window.append(failure)

            ep_rew_mean = (
                float(np.mean(self._ret_window)) if self._ret_window else float("nan")
            )
            ep_len_mean = (
                float(np.mean(self._len_window)) if self._len_window else float("nan")
            )
            avg_success = (
                float(np.mean(self._success_window))
                if self._success_window
                else float("nan")
            )
            avg_failure = (
                float(np.mean(self._failure_window))
                if self._failure_window
                else float("nan")
            )
            success_rate = avg_success

            self.logger.record("rollout/ep_rew_mean", ep_rew_mean)
            self.logger.record("rollout/ep_len_mean", ep_len_mean)
            self.logger.record("rollout/avg_success", avg_success)
            self.logger.record("rollout/avg_failure", avg_failure)
            self.logger.record("rollout/success_rate", success_rate)

            self._ep_writer.writerow(
                {
                    "timesteps": int(self.num_timesteps),
                    "episode": ep_idx,
                    "ep_return": float(self._ep_return),
                    "ep_len": int(self._ep_len),
                    f"rollout_ep_rew_mean_{self.rollout_window}": ep_rew_mean,
                    f"rollout_ep_len_mean_{self.rollout_window}": ep_len_mean,
                    f"rollout_avg_success_{self.rollout_window}": avg_success,
                    f"rollout_avg_failure_{self.rollout_window}": avg_failure,
                    f"rollout_success_rate_{self.rollout_window}": success_rate,
                    "success": int(success),
                    "failure": int(failure),
                    "final_dist": float(
                        info.get("ep_final_dist", info.get("dist_to_goal", float("nan")))
                    ),
                    "path_len": float(info.get("ep_path_len", float("nan"))),
                    "straight_dist": float(info.get("ep_straight_dist", float("nan"))),
                    "path_eff": float(info.get("ep_path_eff", float("nan"))),
                    "reverse_ratio": float(info.get("ep_reverse_ratio", float("nan"))),
                    "heading_abs_mean": float(info.get("ep_heading_abs_mean", float("nan"))),
                    "action_smooth_mean": float(
                        info.get("ep_action_smooth_mean", float("nan"))
                    ),
                }
            )

            if self.verbose > 0:
                print(
                    f"[episode {ep_idx}] "
                    f"return={self._ep_return:.3f} "
                    f"len={self._ep_len} "
                    f"success={int(success)} "
                    f"avg_success={avg_success:.3f} "
                    f"avg_failure={avg_failure:.3f} "
                    f"success_rate={success_rate:.3f}"
                )

            setattr(self, "_episode_idx", ep_idx + 1)
            self._ep_return = 0.0
            self._ep_len = 0

        return True

    def _on_training_end(self) -> None:
        if self._ep_fp is not None:
            self._ep_fp.flush()
            self._ep_fp.close()
        if self._step_fp is not None:
            self._step_fp.flush()
            self._step_fp.close()

# %%
def sample_goal(rng: np.random.Generator):
    r = rng.uniform(1.0, 4.5)
    a = rng.uniform(-math.pi, math.pi)
    return float(r * math.cos(a)), float(r * math.sin(a))


def sample_spawn(rng: np.random.Generator):
    r = rng.uniform(0.0, 1.0)
    a = rng.uniform(-math.pi, math.pi)
    x, y = float(r * math.cos(a)), float(r * math.sin(a))
    theta = float(rng.uniform(-math.pi, math.pi))
    return (x, y), theta

def obstacle_sampler_factory():
    def sampler(rng, start_xy, goal_xy):

        sx, sy = start_xy
        gx, gy = goal_xy

        obstacles = []
        n_obs = rng.integers(2, 6)

        path = np.array([gx - sx, gy - sy])
        path_len = np.linalg.norm(path)

        if path_len < 1e-6:
            return obstacles

        path_dir = path / path_len
        perp = np.array([-path_dir[1], path_dir[0]])

        for _ in range(n_obs):

            r = rng.uniform(0.2, 0.5)

            if rng.random() < 0.8:

                t = rng.uniform(0.2, 0.8)
                base = np.array([sx, sy]) + path * t

                offset = perp * rng.uniform(-0.8, 0.8)

                ox, oy = base + offset

            else:

                ox = rng.uniform(-4.5, 4.5)
                oy = rng.uniform(-4.5, 4.5)

            if np.hypot(ox - sx, oy - sy) < 0.7:
                continue

            if np.hypot(ox - gx, oy - gy) < 0.7:
                continue

            obstacles.append((float(ox), float(oy), float(r)))

        return obstacles

    return sampler

path_obstacle_sampler = obstacle_sampler_factory()

# %%
def make_navigation_env(robot: None, seed: int | None = None):
    def robot_factory():
        if robot:
            return robot
        return TwoWheelRobotWithoutObstacles(
            wheel_distance=0.3,
        )

    return TwoWheelNavigationEnv(
        robot_factory=robot_factory,
        wheel_speed_limit=0.6,
        dt=0.1,
        max_steps=250,
        goal_radius=0.2,
        spawn_sampler=sample_spawn,
        goal_xy_sampler=sample_goal,
        arena_radius=6.0,
        obs_norm_radius=6.0,
        effort_penalty=0.01,
        spin_penalty=0.002,
        stall_penalty=0.05,
        stall_window=12,
        stall_tol=1e-3,
        success_bonus=10.0,
        oob_penalty=2.0,
        allow_reverse=False,
        render_enabled=not False,
        seed=seed,
        render_path="training_outputs/navigation/output.png",
    )

# %%
env = DummyVecEnv([lambda: make_navigation_env(seed=0)])

model = SAC(
    "MlpPolicy",
    env,
    learning_rate=3e-4,
    buffer_size=300_000,
    batch_size=256,
    tau=0.005,
    gamma=0.99,
    train_freq=1,
    gradient_steps=1,
    verbose=1,
)

checkpoint_cb = CheckpointCallback(
    save_freq=10_000,
    save_path="training_outputs/navigation/checkpoints",
    name_prefix="",
    save_replay_buffer=True,
    save_vecnormalize=True,
)

csv__metrics_cb = CSVMetricsLogger(
    path_episodes="training_outputs/navigation/episodes.csv",
)

model.learn(
    total_timesteps=100_000,
    callback=CallbackList(
        [checkpoint_cb, csv__metrics_cb],
    ),
)
model.save("training_outputs/navigation/model.zip")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | -17.2    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 115      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 851      |
# | train/             |          |
# |    actor_loss      | -5.55    |
# |    critic_loss     | 0.0687   |
# |    ent_coef        | 0.799    |
# |    ent_coef_loss   | -0.757   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 750      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | -16.3    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 117      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1798     |
# | train/             |          |
# |    actor_loss      | -8.52    |
# |    critic_loss     | 0.0138   |
# |    ent_coef        | 0.601    |
# |    ent_coef_loss   | -1.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1697     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | -15.9    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 115      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2742     |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.00889  |
# |    ent_coef        | 0.453    |
# |    ent_coef_loss   | -2.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2641     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 220      |
# |    ep_rew_mean     | -12.2    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 116      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 3522     |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 0.00723  |
# |    ent_coef        | 0.359    |
# |    ent_coef_loss   | -3.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3421     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 211      |
# |    ep_rew_mean     | -10.8    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 113      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 4219     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.00678  |
# |    ent_coef        | 0.291    |
# |    ent_coef_loss   | -4.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4118     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 215      |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 113      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 5155     |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.00706  |
# |    ent_coef        | 0.22     |
# |    ent_coef_loss   | -5.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 220      |
# |    ep_rew_mean     | -10      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 111      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 6155     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.00529  |
# |    ent_coef        | 0.163    |
# |    ent_coef_loss   | -5.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6054     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -9.86    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 111      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 7114     |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.0363   |
# |    ent_coef        | 0.123    |
# |    ent_coef_loss   | -6.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7013     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -8.41    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 110      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 7976     |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.0429   |
# |    ent_coef        | 0.0954   |
# |    ent_coef_loss   | -7.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7875     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | -7.46    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 111      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 8850     |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 0.0247   |
# |    ent_coef        | 0.0742   |
# |    ent_coef_loss   | -7.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8749     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | -6.18    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 111      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 9585     |
# | train/             |          |
# |    actor_loss      | -12.7    |
# |    critic_loss     | 0.00547  |
# |    ent_coef        | 0.0604   |
# |    ent_coef_loss   | -7.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9484     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | -5.69    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 111      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 10529    |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.0173   |
# |    ent_coef        | 0.0464   |
# |    ent_coef_loss   | -7.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | -4.7     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 112      |
# |    time_elapsed    | 99       |
# |    total_timesteps | 11151    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.00643  |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | -7.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11050    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | -4.05    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 111      |
# |    time_elapsed    | 106      |
# |    total_timesteps | 11867    |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 0.00652  |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | -8.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11766    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 204      |
# |    ep_rew_mean     | -2.98    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 111      |
# |    time_elapsed    | 110      |
# |    total_timesteps | 12255    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.0069   |
# |    ent_coef        | 0.0285   |
# |    ent_coef_loss   | -8.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12154    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -2.29    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 110      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 12831    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.00607  |
# |    ent_coef        | 0.0242   |
# |    ent_coef_loss   | -8.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12730    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | -1.79    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 109      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 13267    |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 0.00425  |
# |    ent_coef        | 0.0215   |
# |    ent_coef_loss   | -7.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13166    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | -1.13    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 107      |
# |    time_elapsed    | 128      |
# |    total_timesteps | 13909    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.0105   |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | -9.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13808    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 193      |
# |    ep_rew_mean     | -0.644   |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 107      |
# |    time_elapsed    | 136      |
# |    total_timesteps | 14645    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.00525  |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | -7.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14544    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | -0.199   |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 106      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 15244    |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.00797  |
# |    ent_coef        | 0.0125   |
# |    ent_coef_loss   | -7.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15143    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 188      |
# |    ep_rew_mean     | 0.307    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 105      |
# |    time_elapsed    | 149      |
# |    total_timesteps | 15804    |
# | train/             |          |
# |    actor_loss      | -9.91    |
# |    critic_loss     | 0.00737  |
# |    ent_coef        | 0.0107   |
# |    ent_coef_loss   | -6.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15703    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 182      |
# |    ep_rew_mean     | 0.804    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 105      |
# |    time_elapsed    | 152      |
# |    total_timesteps | 16055    |
# | train/             |          |
# |    actor_loss      | -9.88    |
# |    critic_loss     | 0.0108   |
# |    ent_coef        | 0.00999  |
# |    ent_coef_loss   | -7.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15954    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 179      |
# |    ep_rew_mean     | 1.27     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 104      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 16435    |
# | train/             |          |
# |    actor_loss      | -9.6     |
# |    critic_loss     | 0.00748  |
# |    ent_coef        | 0.00901  |
# |    ent_coef_loss   | -7.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | 1.64     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 103      |
# |    time_elapsed    | 163      |
# |    total_timesteps | 17021    |
# | train/             |          |
# |    actor_loss      | -9.34    |
# |    critic_loss     | 0.0216   |
# |    ent_coef        | 0.00776  |
# |    ent_coef_loss   | -5.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16920    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 174      |
# |    ep_rew_mean     | 2.03     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 103      |
# |    time_elapsed    | 167      |
# |    total_timesteps | 17385    |
# | train/             |          |
# |    actor_loss      | -9.19    |
# |    critic_loss     | 0.00442  |
# |    ent_coef        | 0.00713  |
# |    ent_coef_loss   | -7.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17284    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | 3.07     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 103      |
# |    time_elapsed    | 172      |
# |    total_timesteps | 17942    |
# | train/             |          |
# |    actor_loss      | -8.94    |
# |    critic_loss     | 0.00459  |
# |    ent_coef        | 0.00631  |
# |    ent_coef_loss   | -6.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17841    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 165      |
# |    ep_rew_mean     | 4.12     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 103      |
# |    time_elapsed    | 175      |
# |    total_timesteps | 18271    |
# | train/             |          |
# |    actor_loss      | -8.94    |
# |    critic_loss     | 0.026    |
# |    ent_coef        | 0.00587  |
# |    ent_coef_loss   | -5.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18170    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 161      |
# |    ep_rew_mean     | 5.05     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 104      |
# |    time_elapsed    | 180      |
# |    total_timesteps | 18835    |
# | train/             |          |
# |    actor_loss      | -8.71    |
# |    critic_loss     | 0.0183   |
# |    ent_coef        | 0.0052   |
# |    ent_coef_loss   | -4.56    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 156      |
# |    ep_rew_mean     | 5.57     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 104      |
# |    time_elapsed    | 183      |
# |    total_timesteps | 19117    |
# | train/             |          |
# |    actor_loss      | -8.56    |
# |    critic_loss     | 0.00429  |
# |    ent_coef        | 0.0049   |
# |    ent_coef_loss   | -3.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19016    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | 6.21     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 104      |
# |    time_elapsed    | 187      |
# |    total_timesteps | 19569    |
# | train/             |          |
# |    actor_loss      | -8.48    |
# |    critic_loss     | 0.0431   |
# |    ent_coef        | 0.00448  |
# |    ent_coef_loss   | -5.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19468    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 148      |
# |    ep_rew_mean     | 7.09     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 103      |
# |    time_elapsed    | 191      |
# |    total_timesteps | 19932    |
# | train/             |          |
# |    actor_loss      | -8.27    |
# |    critic_loss     | 0.0501   |
# |    ent_coef        | 0.00418  |
# |    ent_coef_loss   | -3.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19831    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | 7.51     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 103      |
# |    time_elapsed    | 198      |
# |    total_timesteps | 20612    |
# | train/             |          |
# |    actor_loss      | -8       |
# |    critic_loss     | 0.0502   |
# |    ent_coef        | 0.00376  |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20511    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | 8.29     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 103      |
# |    time_elapsed    | 202      |
# |    total_timesteps | 21078    |
# | train/             |          |
# |    actor_loss      | -7.88    |
# |    critic_loss     | 0.0264   |
# |    ent_coef        | 0.00355  |
# |    ent_coef_loss   | 0.412    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20977    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 137      |
# |    ep_rew_mean     | 8.52     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 103      |
# |    time_elapsed    | 208      |
# |    total_timesteps | 21651    |
# | train/             |          |
# |    actor_loss      | -7.73    |
# |    critic_loss     | 0.0287   |
# |    ent_coef        | 0.00341  |
# |    ent_coef_loss   | -1.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21550    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | 8.8      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 104      |
# |    time_elapsed    | 214      |
# |    total_timesteps | 22342    |
# | train/             |          |
# |    actor_loss      | -7.49    |
# |    critic_loss     | 0.0598   |
# |    ent_coef        | 0.00357  |
# |    ent_coef_loss   | -0.0573  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22241    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 9        |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 104      |
# |    time_elapsed    | 219      |
# |    total_timesteps | 22876    |
# | train/             |          |
# |    actor_loss      | -7.36    |
# |    critic_loss     | 0.0556   |
# |    ent_coef        | 0.00375  |
# |    ent_coef_loss   | -0.596   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22775    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | 9.13     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 104      |
# |    time_elapsed    | 227      |
# |    total_timesteps | 23777    |
# | train/             |          |
# |    actor_loss      | -7.13    |
# |    critic_loss     | 0.0396   |
# |    ent_coef        | 0.00365  |
# |    ent_coef_loss   | -0.341   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23676    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 9.16     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 104      |
# |    time_elapsed    | 234      |
# |    total_timesteps | 24488    |
# | train/             |          |
# |    actor_loss      | -7.06    |
# |    critic_loss     | 0.00653  |
# |    ent_coef        | 0.00347  |
# |    ent_coef_loss   | 0.707    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24387    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | 9.11     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 104      |
# |    time_elapsed    | 241      |
# |    total_timesteps | 25236    |
# | train/             |          |
# |    actor_loss      | -6.91    |
# |    critic_loss     | 0.00536  |
# |    ent_coef        | 0.00375  |
# |    ent_coef_loss   | 0.618    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25135    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 135      |
# |    ep_rew_mean     | 9.07     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 104      |
# |    time_elapsed    | 245      |
# |    total_timesteps | 25714    |
# | train/             |          |
# |    actor_loss      | -6.86    |
# |    critic_loss     | 0.0568   |
# |    ent_coef        | 0.00386  |
# |    ent_coef_loss   | -1.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25613    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 9.16     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 104      |
# |    time_elapsed    | 249      |
# |    total_timesteps | 26154    |
# | train/             |          |
# |    actor_loss      | -6.74    |
# |    critic_loss     | 0.056    |
# |    ent_coef        | 0.00384  |
# |    ent_coef_loss   | -0.697   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26053    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 9.37     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 104      |
# |    time_elapsed    | 253      |
# |    total_timesteps | 26604    |
# | train/             |          |
# |    actor_loss      | -6.65    |
# |    critic_loss     | 0.0282   |
# |    ent_coef        | 0.00378  |
# |    ent_coef_loss   | 0.0577   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26503    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 9.44     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 104      |
# |    time_elapsed    | 256      |
# |    total_timesteps | 26913    |
# | train/             |          |
# |    actor_loss      | -6.74    |
# |    critic_loss     | 0.0777   |
# |    ent_coef        | 0.00383  |
# |    ent_coef_loss   | 0.607    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26812    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 9.53     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 104      |
# |    time_elapsed    | 260      |
# |    total_timesteps | 27319    |
# | train/             |          |
# |    actor_loss      | -6.7     |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.00408  |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27218    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | 9.64     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 104      |
# |    time_elapsed    | 265      |
# |    total_timesteps | 27820    |
# | train/             |          |
# |    actor_loss      | -6.54    |
# |    critic_loss     | 0.0871   |
# |    ent_coef        | 0.00404  |
# |    ent_coef_loss   | -0.846   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27719    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 9.52     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 104      |
# |    time_elapsed    | 271      |
# |    total_timesteps | 28472    |
# | train/             |          |
# |    actor_loss      | -6.54    |
# |    critic_loss     | 0.0148   |
# |    ent_coef        | 0.00436  |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28371    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 9.52     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 102      |
# |    time_elapsed    | 283      |
# |    total_timesteps | 28983    |
# | train/             |          |
# |    actor_loss      | -6.43    |
# |    critic_loss     | 0.0084   |
# |    ent_coef        | 0.00465  |
# |    ent_coef_loss   | 0.285    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28882    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 9.53     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 102      |
# |    time_elapsed    | 287      |
# |    total_timesteps | 29431    |
# | train/             |          |
# |    actor_loss      | -6.29    |
# |    critic_loss     | 0.0293   |
# |    ent_coef        | 0.0048   |
# |    ent_coef_loss   | 0.748    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29330    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 9.59     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 102      |
# |    time_elapsed    | 292      |
# |    total_timesteps | 30036    |
# | train/             |          |
# |    actor_loss      | -6.26    |
# |    critic_loss     | 0.0265   |
# |    ent_coef        | 0.00488  |
# |    ent_coef_loss   | 1.25     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29935    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | 9.56     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 102      |
# |    time_elapsed    | 296      |
# |    total_timesteps | 30453    |
# | train/             |          |
# |    actor_loss      | -6.41    |
# |    critic_loss     | 0.0321   |
# |    ent_coef        | 0.00503  |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30352    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 9.65     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 102      |
# |    time_elapsed    | 300      |
# |    total_timesteps | 30871    |
# | train/             |          |
# |    actor_loss      | -6.31    |
# |    critic_loss     | 0.0101   |
# |    ent_coef        | 0.00515  |
# |    ent_coef_loss   | 0.896    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30770    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | 9.66     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 102      |
# |    time_elapsed    | 305      |
# |    total_timesteps | 31412    |
# | train/             |          |
# |    actor_loss      | -6.24    |
# |    critic_loss     | 0.0525   |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | 0.071    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 9.8      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 102      |
# |    time_elapsed    | 308      |
# |    total_timesteps | 31723    |
# | train/             |          |
# |    actor_loss      | -6.32    |
# |    critic_loss     | 0.0263   |
# |    ent_coef        | 0.00536  |
# |    ent_coef_loss   | 0.622    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31622    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 9.79     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 103      |
# |    time_elapsed    | 310      |
# |    total_timesteps | 32005    |
# | train/             |          |
# |    actor_loss      | -6.36    |
# |    critic_loss     | 0.0241   |
# |    ent_coef        | 0.00545  |
# |    ent_coef_loss   | 0.514    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31904    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 9.84     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 103      |
# |    time_elapsed    | 314      |
# |    total_timesteps | 32442    |
# | train/             |          |
# |    actor_loss      | -6.26    |
# |    critic_loss     | 0.0822   |
# |    ent_coef        | 0.00576  |
# |    ent_coef_loss   | -0.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32341    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | 9.89     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 103      |
# |    time_elapsed    | 317      |
# |    total_timesteps | 32759    |
# | train/             |          |
# |    actor_loss      | -6.24    |
# |    critic_loss     | 0.0397   |
# |    ent_coef        | 0.00568  |
# |    ent_coef_loss   | 0.557    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32658    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 103      |
# |    time_elapsed    | 320      |
# |    total_timesteps | 33159    |
# | train/             |          |
# |    actor_loss      | -6.11    |
# |    critic_loss     | 0.00753  |
# |    ent_coef        | 0.00575  |
# |    ent_coef_loss   | 0.317    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33058    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 103      |
# |    time_elapsed    | 323      |
# |    total_timesteps | 33528    |
# | train/             |          |
# |    actor_loss      | -6.15    |
# |    critic_loss     | 0.0176   |
# |    ent_coef        | 0.00585  |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33427    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 10.2     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 101      |
# |    time_elapsed    | 332      |
# |    total_timesteps | 33836    |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 0.0292   |
# |    ent_coef        | 0.0059   |
# |    ent_coef_loss   | 0.181    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33735    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 101      |
# |    time_elapsed    | 336      |
# |    total_timesteps | 34178    |
# | train/             |          |
# |    actor_loss      | -6.3     |
# |    critic_loss     | 0.0204   |
# |    ent_coef        | 0.00589  |
# |    ent_coef_loss   | 0.443    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34077    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 101      |
# |    time_elapsed    | 339      |
# |    total_timesteps | 34538    |
# | train/             |          |
# |    actor_loss      | -6.28    |
# |    critic_loss     | 0.0317   |
# |    ent_coef        | 0.00599  |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34437    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 111      |
# |    ep_rew_mean     | 10.7     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 101      |
# |    time_elapsed    | 342      |
# |    total_timesteps | 34846    |
# | train/             |          |
# |    actor_loss      | -6.19    |
# |    critic_loss     | 0.0168   |
# |    ent_coef        | 0.00623  |
# |    ent_coef_loss   | 0.461    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34745    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 101      |
# |    time_elapsed    | 344      |
# |    total_timesteps | 35104    |
# | train/             |          |
# |    actor_loss      | -6.24    |
# |    critic_loss     | 0.00843  |
# |    ent_coef        | 0.00631  |
# |    ent_coef_loss   | 0.0477   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35003    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 11.2     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 101      |
# |    time_elapsed    | 348      |
# |    total_timesteps | 35479    |
# | train/             |          |
# |    actor_loss      | -6.18    |
# |    critic_loss     | 0.00895  |
# |    ent_coef        | 0.00623  |
# |    ent_coef_loss   | 0.167    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35378    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 101      |
# |    time_elapsed    | 351      |
# |    total_timesteps | 35889    |
# | train/             |          |
# |    actor_loss      | -6.23    |
# |    critic_loss     | 0.0249   |
# |    ent_coef        | 0.00607  |
# |    ent_coef_loss   | 2        |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35788    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 102      |
# |    time_elapsed    | 355      |
# |    total_timesteps | 36278    |
# | train/             |          |
# |    actor_loss      | -6.42    |
# |    critic_loss     | 0.0277   |
# |    ent_coef        | 0.00614  |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36177    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.3     |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 102      |
# |    time_elapsed    | 357      |
# |    total_timesteps | 36532    |
# | train/             |          |
# |    actor_loss      | -6.51    |
# |    critic_loss     | 0.0915   |
# |    ent_coef        | 0.00619  |
# |    ent_coef_loss   | -0.385   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36431    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 11.3     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 102      |
# |    time_elapsed    | 361      |
# |    total_timesteps | 36924    |
# | train/             |          |
# |    actor_loss      | -6.38    |
# |    critic_loss     | 0.0285   |
# |    ent_coef        | 0.00616  |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36823    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.8     |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 102      |
# |    time_elapsed    | 364      |
# |    total_timesteps | 37203    |
# | train/             |          |
# |    actor_loss      | -6.42    |
# |    critic_loss     | 0.0642   |
# |    ent_coef        | 0.00631  |
# |    ent_coef_loss   | 0.779    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37102    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.8     |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 102      |
# |    time_elapsed    | 366      |
# |    total_timesteps | 37495    |
# | train/             |          |
# |    actor_loss      | -6.47    |
# |    critic_loss     | 0.0372   |
# |    ent_coef        | 0.00633  |
# |    ent_coef_loss   | -0.315   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37394    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.5     |
# |    ep_rew_mean     | 11.6     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 102      |
# |    time_elapsed    | 369      |
# |    total_timesteps | 37825    |
# | train/             |          |
# |    actor_loss      | -6.37    |
# |    critic_loss     | 0.00846  |
# |    ent_coef        | 0.00641  |
# |    ent_coef_loss   | -0.0118  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37724    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.5     |
# |    ep_rew_mean     | 11.7     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 102      |
# |    time_elapsed    | 372      |
# |    total_timesteps | 38136    |
# | train/             |          |
# |    actor_loss      | -6.09    |
# |    critic_loss     | 0.0223   |
# |    ent_coef        | 0.00661  |
# |    ent_coef_loss   | 0.968    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38035    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90       |
# |    ep_rew_mean     | 11.7     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 28       |
# |    time_elapsed    | 1355     |
# |    total_timesteps | 38435    |
# | train/             |          |
# |    actor_loss      | -6.27    |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.00662  |
# |    ent_coef_loss   | 0.424    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38334    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.3     |
# |    ep_rew_mean     | 11.7     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 28       |
# |    time_elapsed    | 1357     |
# |    total_timesteps | 38669    |
# | train/             |          |
# |    actor_loss      | -6.54    |
# |    critic_loss     | 0.0467   |
# |    ent_coef        | 0.00662  |
# |    ent_coef_loss   | 0.607    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38568    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.1     |
# |    ep_rew_mean     | 11.7     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 28       |
# |    time_elapsed    | 1359     |
# |    total_timesteps | 38963    |
# | train/             |          |
# |    actor_loss      | -6.43    |
# |    critic_loss     | 0.0122   |
# |    ent_coef        | 0.00663  |
# |    ent_coef_loss   | -0.307   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38862    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 16       |
# |    time_elapsed    | 2398     |
# |    total_timesteps | 39213    |
# | train/             |          |
# |    actor_loss      | -6.41    |
# |    critic_loss     | 0.00633  |
# |    ent_coef        | 0.00658  |
# |    ent_coef_loss   | -0.759   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39112    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.9     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 16       |
# |    time_elapsed    | 2399     |
# |    total_timesteps | 39405    |
# | train/             |          |
# |    actor_loss      | -6.4     |
# |    critic_loss     | 0.0229   |
# |    ent_coef        | 0.00652  |
# |    ent_coef_loss   | 0.71     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39304    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.7     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 16       |
# |    time_elapsed    | 2401     |
# |    total_timesteps | 39589    |
# | train/             |          |
# |    actor_loss      | -6.44    |
# |    critic_loss     | 0.0503   |
# |    ent_coef        | 0.00642  |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39488    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.3     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 16       |
# |    time_elapsed    | 2403     |
# |    total_timesteps | 39835    |
# | train/             |          |
# |    actor_loss      | -6.47    |
# |    critic_loss     | 0.00698  |
# |    ent_coef        | 0.00636  |
# |    ent_coef_loss   | -0.804   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.5     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 11       |
# |    time_elapsed    | 3421     |
# |    total_timesteps | 40090    |
# | train/             |          |
# |    actor_loss      | -6.6     |
# |    critic_loss     | 0.00615  |
# |    ent_coef        | 0.00627  |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39989    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.3     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 11       |
# |    time_elapsed    | 3423     |
# |    total_timesteps | 40389    |
# | train/             |          |
# |    actor_loss      | -6.42    |
# |    critic_loss     | 0.0317   |
# |    ent_coef        | 0.00622  |
# |    ent_coef_loss   | 0.943    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40288    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.4     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 11       |
# |    time_elapsed    | 3425     |
# |    total_timesteps | 40602    |
# | train/             |          |
# |    actor_loss      | -6.51    |
# |    critic_loss     | 0.0157   |
# |    ent_coef        | 0.00629  |
# |    ent_coef_loss   | -0.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40501    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.6     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 9        |
# |    time_elapsed    | 4394     |
# |    total_timesteps | 40886    |
# | train/             |          |
# |    actor_loss      | -6.54    |
# |    critic_loss     | 0.0248   |
# |    ent_coef        | 0.00631  |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40785    |
# ---------------------------------
# ...
# |    fps             | 5        |
# |    time_elapsed    | 17086    |
# |    total_timesteps | 93884    |
# | train/             |          |
# |    actor_loss      | -8.15    |
# |    critic_loss     | 0.00134  |
# |    ent_coef        | 0.00548  |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93783    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.1     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 1264     |
# |    fps             | 5        |
# |    time_elapsed    | 17087    |
# |    total_timesteps | 94040    |
# | train/             |          |
# |    actor_loss      | -7.98    |
# |    critic_loss     | 0.00183  |
# |    ent_coef        | 0.00546  |
# |    ent_coef_loss   | 0.758    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93939    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.9     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1268     |
# |    fps             | 5        |
# |    time_elapsed    | 17089    |
# |    total_timesteps | 94306    |
# | train/             |          |
# |    actor_loss      | -8.07    |
# |    critic_loss     | 0.000887 |
# |    ent_coef        | 0.00545  |
# |    ent_coef_loss   | -0.454   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94205    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.8     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1272     |
# |    fps             | 5        |
# |    time_elapsed    | 17091    |
# |    total_timesteps | 94526    |
# | train/             |          |
# |    actor_loss      | -7.91    |
# |    critic_loss     | 0.00132  |
# |    ent_coef        | 0.00546  |
# |    ent_coef_loss   | 0.589    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94425    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.2     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1276     |
# |    fps             | 5        |
# |    time_elapsed    | 17093    |
# |    total_timesteps | 94724    |
# | train/             |          |
# |    actor_loss      | -8.14    |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.00547  |
# |    ent_coef_loss   | 0.562    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94623    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.1     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1280     |
# |    fps             | 5        |
# |    time_elapsed    | 17096    |
# |    total_timesteps | 95009    |
# | train/             |          |
# |    actor_loss      | -8.13    |
# |    critic_loss     | 0.00126  |
# |    ent_coef        | 0.00545  |
# |    ent_coef_loss   | 0.442    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94908    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.3     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1284     |
# |    fps             | 5        |
# |    time_elapsed    | 17097    |
# |    total_timesteps | 95210    |
# | train/             |          |
# |    actor_loss      | -7.94    |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.00537  |
# |    ent_coef_loss   | -1.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95109    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.6     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1288     |
# |    fps             | 5        |
# |    time_elapsed    | 17099    |
# |    total_timesteps | 95372    |
# | train/             |          |
# |    actor_loss      | -8.13    |
# |    critic_loss     | 0.00216  |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | 0.23     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95271    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52       |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 1292     |
# |    fps             | 5        |
# |    time_elapsed    | 17100    |
# |    total_timesteps | 95560    |
# | train/             |          |
# |    actor_loss      | -7.98    |
# |    critic_loss     | 0.000711 |
# |    ent_coef        | 0.00541  |
# |    ent_coef_loss   | -0.594   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95459    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.5     |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 1296     |
# |    fps             | 5        |
# |    time_elapsed    | 17102    |
# |    total_timesteps | 95725    |
# | train/             |          |
# |    actor_loss      | -8.22    |
# |    critic_loss     | 0.00165  |
# |    ent_coef        | 0.00544  |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95624    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.6     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 5        |
# |    time_elapsed    | 17104    |
# |    total_timesteps | 96010    |
# | train/             |          |
# |    actor_loss      | -8.08    |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.00541  |
# |    ent_coef_loss   | -0.422   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95909    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.5     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1304     |
# |    fps             | 5        |
# |    time_elapsed    | 17106    |
# |    total_timesteps | 96233    |
# | train/             |          |
# |    actor_loss      | -8.03    |
# |    critic_loss     | 0.0013   |
# |    ent_coef        | 0.0054   |
# |    ent_coef_loss   | -0.165   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96132    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.2     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1308     |
# |    fps             | 5        |
# |    time_elapsed    | 17108    |
# |    total_timesteps | 96429    |
# | train/             |          |
# |    actor_loss      | -8.12    |
# |    critic_loss     | 0.000676 |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | -1.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96328    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.3     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1312     |
# |    fps             | 5        |
# |    time_elapsed    | 17110    |
# |    total_timesteps | 96682    |
# | train/             |          |
# |    actor_loss      | -8.08    |
# |    critic_loss     | 0.00169  |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96581    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.1     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1316     |
# |    fps             | 5        |
# |    time_elapsed    | 17112    |
# |    total_timesteps | 96835    |
# | train/             |          |
# |    actor_loss      | -8.12    |
# |    critic_loss     | 0.00103  |
# |    ent_coef        | 0.0053   |
# |    ent_coef_loss   | 0.109    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53       |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1320     |
# |    fps             | 5        |
# |    time_elapsed    | 17114    |
# |    total_timesteps | 97101    |
# | train/             |          |
# |    actor_loss      | -8.03    |
# |    critic_loss     | 0.000877 |
# |    ent_coef        | 0.00536  |
# |    ent_coef_loss   | -0.766   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52       |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1324     |
# |    fps             | 5        |
# |    time_elapsed    | 17116    |
# |    total_timesteps | 97309    |
# | train/             |          |
# |    actor_loss      | -7.96    |
# |    critic_loss     | 0.000921 |
# |    ent_coef        | 0.00537  |
# |    ent_coef_loss   | -0.383   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97208    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.7     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1328     |
# |    fps             | 5        |
# |    time_elapsed    | 17118    |
# |    total_timesteps | 97575    |
# | train/             |          |
# |    actor_loss      | -8.21    |
# |    critic_loss     | 0.00165  |
# |    ent_coef        | 0.00531  |
# |    ent_coef_loss   | -0.899   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97474    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.6     |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 1332     |
# |    fps             | 5        |
# |    time_elapsed    | 17121    |
# |    total_timesteps | 97832    |
# | train/             |          |
# |    actor_loss      | -8.19    |
# |    critic_loss     | 0.00137  |
# |    ent_coef        | 0.00533  |
# |    ent_coef_loss   | -0.0233  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97731    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.1     |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 1336     |
# |    fps             | 5        |
# |    time_elapsed    | 17123    |
# |    total_timesteps | 98098    |
# | train/             |          |
# |    actor_loss      | -7.94    |
# |    critic_loss     | 0.00132  |
# |    ent_coef        | 0.00531  |
# |    ent_coef_loss   | 0.625    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97997    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.4     |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 1340     |
# |    fps             | 5        |
# |    time_elapsed    | 17125    |
# |    total_timesteps | 98370    |
# | train/             |          |
# |    actor_loss      | -8.07    |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98269    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.9     |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 1344     |
# |    fps             | 5        |
# |    time_elapsed    | 17127    |
# |    total_timesteps | 98612    |
# | train/             |          |
# |    actor_loss      | -8.18    |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.00534  |
# |    ent_coef_loss   | 0.0511   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98511    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.9     |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 1348     |
# |    fps             | 5        |
# |    time_elapsed    | 17130    |
# |    total_timesteps | 98868    |
# | train/             |          |
# |    actor_loss      | -8.1     |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.00531  |
# |    ent_coef_loss   | 1.85     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98767    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56       |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 1352     |
# |    fps             | 5        |
# |    time_elapsed    | 17132    |
# |    total_timesteps | 99133    |
# | train/             |          |
# |    actor_loss      | -8.24    |
# |    critic_loss     | 0.00092  |
# |    ent_coef        | 0.00527  |
# |    ent_coef_loss   | -0.467   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99032    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.2     |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 1356     |
# |    fps             | 5        |
# |    time_elapsed    | 17135    |
# |    total_timesteps | 99436    |
# | train/             |          |
# |    actor_loss      | -8.07    |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | 0.379    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99335    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.9     |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 1360     |
# |    fps             | 5        |
# |    time_elapsed    | 17136    |
# |    total_timesteps | 99578    |
# | train/             |          |
# |    actor_loss      | -8.08    |
# |    critic_loss     | 0.000899 |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | -0.189   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99477    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.5     |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 1364     |
# |    fps             | 5        |
# |    time_elapsed    | 17138    |
# |    total_timesteps | 99788    |
# | train/             |          |
# |    actor_loss      | -8.18    |
# |    critic_loss     | 0.00343  |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99687    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.4     |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 1368     |
# |    fps             | 5        |
# |    time_elapsed    | 17139    |
# |    total_timesteps | 99947    |
# | train/             |          |
# |    actor_loss      | -7.95    |
# |    critic_loss     | 0.00152  |
# |    ent_coef        | 0.00529  |
# |    ent_coef_loss   | -0.656   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99846    |
# ---------------------------------

# %%
from time import time


r = TwoWheelRobotWithoutObstacles(
    wheel_distance=0.3,
)

an_env = make_navigation_env(robot=r)

model = SAC.load("training_outputs/navigation/model.zip")
obs, _ = an_env.reset(
    goal_xy=(0, -3),
    robot_pos=(0, 0, 0),
    reset_robot=True,
    seed=int(time()),
)

while True:
    action, _ = model.predict(obs)

    obs, _, terminated, truncated, _ = an_env.step(action)
    x, y, t = r.state()
    if terminated or truncated:
        break

print("Done")
# Out:
# D=>  3.000138201373331
# -0.1741528150935968
# D=>  2.99568652921162
# -0.34206810531516874
# D=>  2.984785564510857
# -0.49713225848972803
# D=>  2.9718280943688127
# -0.6558302895476422
# D=>  2.954096992244283
# -0.8427549948294959
# D=>  2.929319432232743
# -0.9902302076419196
# D=>  2.904069000833189
# -1.1734938522179923
# D=>  2.8715888147478585
# -1.3231656501690547
# D=>  2.827798179900725
# -1.3491289963324866
# D=>  2.77431790573254
# -1.3605994532505672
# D=>  2.7181806387055247
# -1.360346570611
# D=>  2.6732067765395047
# -1.42140631377697
# D=>  2.6276987676756436
# -1.369109645485878
# D=>  2.576344851546665
# -1.3943924556175868
# D=>  2.5232424701203042
# -1.3971564422051113
# D=>  2.4862740213105643
# -1.4400789588689804
# D=>  2.4322269514778703
# -1.459435408314069
# D=>  2.3757927058893222
# -1.4704115241765976
# D=>  2.3273732354985115
# -1.5162504762411118
# D=>  2.273218245084043
# -1.5355893621842067
# D=>  2.216064658402956
# -1.5282731701930365
# D=>  2.161387498786928
# -1.5191511362791064
# D=>  2.1108797950815914
# -1.4706157197554908
# D=>  2.058992373848703
# -1.481812114516894
# D=>  2.0064939387565217
# -1.4896518339713416
# D=>  1.960139370083072
# -1.550605023900668
# D=>  1.9208546828440414
# -1.6498067329327266
# D=>  1.8688076616657001
# -1.6407611320416133
# D=>  1.8124824574896012
# -1.649626448750496
# D=>  1.7576252796303926
# -1.645701602101326
# D=>  1.7019318810508892
# -1.62972787519296
# D=>  1.6463272578978292
# -1.6489376773436863
# D=>  1.594806936373477
# -1.7002477099498112
# D=>  1.537280112623268
# -1.6941343794266381
# D=>  1.4802389750323286
# -1.7064895878235498
# D=>  1.4242531292780476
# -1.7033322900533674
# D=>  1.367605681608832
# -1.7044324725866316
# D=>  1.3120476680933166
# -1.703101779023806
# D=>  1.2591446845059349
# -1.7055972864230473
# D=>  1.2051382330158356
# -1.726367935538292
# D=>  1.1502501222734784
# -1.7574684470891953
# D=>  1.1023472908221366
# -1.8269277463356655
# D=>  1.0471868521826535
# -1.824134036898613
# D=>  0.9940410827259818
# -1.7857365558544795
# D=>  0.9380816552027584
# -1.7639534622430801
# D=>  0.8845941928876618
# -1.7998192459344864
# D=>  0.8266173903896777
# -1.7878258973360062
# D=>  0.7682406014562239
# -1.777902141213417
# D=>  0.7109658606709676
# -1.765788808465004
# D=>  0.6553760555743291
# -1.745702678958575
# D=>  0.596341249803994
# -1.7461112886667252
# D=>  0.5377983260687659
# -1.7406131376822789
# D=>  0.4833703180479919
# -1.7230976571639378
# D=>  0.4271842934759897
# -1.7183196892340977
# D=>  0.3732279389083877
# -1.74884990354379
# D=>  0.32001467378007475
# -1.7542100300391514
# D=>  0.2616046158838153
# -1.7479664832353592
# D=>  0.2102071507626892
# -1.7985709259907405
# D=>  0.15683451467416654
# -1.7752420455217361
# Done
